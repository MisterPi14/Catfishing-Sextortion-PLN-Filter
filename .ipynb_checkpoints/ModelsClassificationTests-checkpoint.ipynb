# %%
# 1. IMPORTACIÓN DE LIBRERÍAS
from ollama import Client
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
import random

# 2. CONEXIÓN CON OLLAMA
client = Client(host='http://localhost:11434')  # Asegúrate que Ollama esté corriendo

# 3. DEFINICIÓN DEL MODELO A USAR
MODEL_NAME = 'deepseek-r1'  # Cambia a 'mistral', 'phi3', etc., según tus modelos locales

# 4. DATASET DE PRUEBA (puedes cargarlo desde un CSV o JSON también)
dataset = [
    {"text": "Hola, soy un soldado en misión en Siria. Necesito que me ayudes con algo urgente.", "label": "1"},
    {"text": "Hola, ¿cómo estás? ¿Quieres salir este fin de semana?", "label": "0"},
    {"text": "Buen día, le informamos sobre su próxima cita médica.", "label": "0"},
    {"text": "Hola hermosa, vi tu perfil y me encantó. ¿Te gustaría conocernos mejor? Soy ingeniero en Monterrey.", "label": "1"},
    {"text": "¡Qué onda! ¿Vamos por unas chelas al rato o qué?", "label": "0"},
    {"text": "Mi nombre es Laura, soy enfermera en Cancún. Me encantaría platicar contigo y ver si tenemos química.", "label": "1"},
    {"text": "No olvides que mañana tienes tu cita con el dentista a las 10:00 AM.", "label": "0"},
    {"text": "Hola guapo, estoy buscando a alguien especial. ¿Te animas a una videollamada?", "label": "1"},
    {"text": "¿Puedes pasar por el súper y comprar leche y pan, porfa?", "label": "0"},
    {"text": "Soy Mariana, modelo de Guadalajara. Me encantaría que me conocieras mejor. ¿Te gustaría ver más fotos mías?", "label": "1"},
    {"text": "Recuerda que el pago de la luz vence el viernes. No se te pase.", "label": "0"},
    {"text": "Estoy en una misión humanitaria en África y necesito ayuda para regresar a casa. ¿Podrías apoyarme económicamente?", "label": "1"},
    {"text": "¡Feliz cumpleaños! Espero que tengas un día increíble lleno de alegría.", "label": "0"},
    {"text": "Soy piloto y estaré en tu ciudad la próxima semana. ¿Te gustaría que nos conociéramos?", "label": "1"},
    {"text": "Te mandé el archivo por correo. Avísame si lo recibiste.", "label": "0"},
    {"text": "Mi ex me dejó y estoy buscando a alguien que me valore. ¿Te gustaría ser esa persona?", "label": "1"},
    {"text": "La junta se reprogramó para el jueves a las 3 PM. Por favor, confirma tu asistencia.", "label": "0"},
    {"text": "Estoy atrapado en el aeropuerto sin dinero. ¿Podrías enviarme algo para poder regresar?", "label": "1"},
    {"text": "¿Viste el partido de anoche? ¡Estuvo buenísimo!", "label": "0"},
    {"text": "Soy chef y me encanta cocinar para alguien especial. ¿Te gustaría probar mis platillos?", "label": "1"},
    {"text": "Mamá, llegué bien a casa. Te quiero mucho.", "label": "0"},
    {"text": "Estoy en una situación difícil y necesito a alguien en quien confiar. ¿Puedo contar contigo?", "label": "1"},
    {"text": "No olvides llevar tu paraguas. Parece que va a llover hoy.", "label": "0"},
]

# 5. FUNCIÓN PARA OBTENER PREDICCIÓN DEL MODELO
def get_model_prediction(model_name, input_text):
    prompt = (
        f"Clasifica este mensaje como catfishing (término referido a la fabricación de una identidad falsa online por parte de un ciberdelincuente con fines de engaño, fraude o explotación. "
        f"El catfishing se utiliza más comúnmente para estafas románticas en aplicaciones de citas, sitios web y plataformas de redes sociales.) "
        f"Imprime solo 1 si detectas catfishing o 0 si no. No des ninguna explicación adicional.\n\n"
        f"Mensaje: \"{input_text}\"\n\n"
        f"Categoría:"
    )

    # Solicitud al modelo en modo streaming
    stream_response = client.chat(
        model=model_name,
        messages=[{"role": "user", "content": prompt}],
        stream=True
    )

    response_text = ""
    print("📡 Generando respuesta en streaming:", end=" ")

    # Token por token
    for chunk in stream_response:
        token = chunk['message']['content']
        print(token, end="", flush=True)  # Impresión en tiempo real
        response_text += token

    print("\n")  # salto de línea final

    # Limpieza de respuesta
    prediction = response_text.strip().lower()
    
    # Solo devolver 1 o 0, aunque el modelo diga más cosas
    if '1' in prediction:
        return '1'
    elif '0' in prediction:
        return '0'
    else:
        return prediction  # fallback por si hay un error inesperado



# 6. REALIZAR PREDICCIONES
true_labels = []
predicted_labels = []

for sample in dataset:
    text = sample["text"]
    label = sample["label"]
    
    prediction = get_model_prediction(MODEL_NAME, text)
    
    print(f"Texto: {text}")
    print(f"Etiqueta real: {label} | Predicción: {prediction}\n")
    
    true_labels.append(label)
    predicted_labels.append(prediction)

# 7. MÉTRICAS DE EVALUACIÓN
print("== MÉTRICAS DE EVALUACIÓN ==")
print("Accuracy:", accuracy_score(true_labels, predicted_labels))
print("Precision (macro):", precision_score(true_labels, predicted_labels, average='macro', zero_division=0))
print("Recall (macro):", recall_score(true_labels, predicted_labels, average='macro', zero_division=0))
print("F1 Score (macro):", f1_score(true_labels, predicted_labels, average='macro', zero_division=0))

# Reporte detallado
print("\n== REPORTE DE CLASIFICACIÓN COMPLETO ==")
print(classification_report(true_labels, predicted_labels, zero_division=0))
# Out:
# Texto: Hola, soy un soldado en misión en Siria. Necesito que me ayudes con algo urgente.
# Etiqueta real: 1 | Predicción: <think>
# okay, so i have to determine whether the given message is a catfishing attempt or not. the term refers to fake identity creation online by cybercriminals for cheating, fraud, or exploitation. it's often used in romantic estaffs on apps like dating sites, websites, and social media platforms.
#
# the message says: "hola, soy un soldado en misión en siria. necesito que me ayudes con algo urgente." translating this roughly means "hello, i'm a soldier on mission in syria. i need your help with something urgent."
#
# first, let's analyze the content. the user is claiming to be a soldier from syria and asking for help urgently. that could be genuine or fake. cybercriminals might pose as soldiers to defraud others, maybe for money, information, or goods.
#
# is there any indication of a fake identity? the message itself doesn't contain obvious red flags like multiple languages (but it's spanish), hidden messages, or repeated contact requests typical in catfishing. it seems straightforward: someone claiming to be a soldier needs help.
#
# however, the urgency might be a sign. if it's an urgent request without context, it could be a scam. but given that it's just a simple message asking for assistance, it's hard to tell if it's real or fake based solely on this.
#
# there's no mention of requests for personal information, financial transactions, or promises of favors in return. the urgency is there but not detailed enough to confirm it's catfishing.
#
# so, considering all factors—content and context—it doesn't strongly indicate catfishing because there's no clear evidence of a fake identity being used for fraudulent purposes.
# </think>
#
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 60
#      57 text = sample["text"]
#      58 label = sample["label"]
# ---> 60 prediction = get_model_prediction(MODEL_NAME, text)
#      62 print(f"Texto: {text}")
#      63 print(f"Etiqueta real: {label} | Predicción: {prediction}\n")
#
# Cell In[32], line 46, in get_model_prediction(model_name, input_text)
#      40 def get_model_prediction(model_name, input_text):
#      41     prompt = (
#      42         f"Clasifica este mensaje como catfishing (termino referido a la fabricación de una identidad falsa online por parte de un ciberdelincuente con fines de engaño, fraude o explotación. El catfishing, se utiliza más comúnmente para estafas “románticas” en aplicaciones de citas, sitios web y plataformas de medios sociales.) only print 1 if there is catfhising or 0 if dont, dont give any other text on your response.\n\n"
#      43         f"Mensaje: \"{input_text}\"\n\n"
#      44         f"Categoría:"
#      45     )
# ---> 46     response = client.chat(
#      47         model=model_name,
#      48         messages=[{"role": "user", "content": prompt}]
#      49     )
#      50     return response['message']['content'].strip().lower()
#
# File ~\anaconda3\Lib\site-packages\ollama\_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)
#     298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)
#     331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File ~\anaconda3\Lib\site-packages\ollama\_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\Lib\site-packages\ollama\_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\anaconda3\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
